# %% [markdown]
# # 🚀 OmniVoice - Finální Stabilní Start
# **⚠️ DŮLEŽITÉ:** Před spuštěním zapni GPU: Runtime -> Change runtime type -> T4 GPU.

# %%
from google.colab import drive
import os
import sys

drive.mount('/content/drive')

REPO_URL = "https://github.com/Brkoszov/Omnivoice.git"
PROJECT_DIR = "/content/Omnivoice"
DRIVE_MODELS_PATH = "/content/drive/MyDrive/OmniVoice_Models"

if not os.path.exists(PROJECT_DIR):
    # !git clone {REPO_URL} {PROJECT_DIR}
else:
    # %cd {PROJECT_DIR}
    # !git pull

if os.getcwd() != PROJECT_DIR:
    # %cd {PROJECT_DIR}

MODELS_TARGET_DIR = os.path.join(PROJECT_DIR, "models")
if os.path.exists(MODELS_TARGET_DIR):
    # !rm -rf {MODELS_TARGET_DIR}
# !ln -s {DRIVE_MODELS_PATH} {MODELS_TARGET_DIR}
print("✅ Projekt a modely připraveny.")
# Out:
# Mounted at /content/drive
# Cloning into '/content/Omnivoice'...
# remote: Enumerating objects: 147, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 147 (delta 42), reused 146 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (147/147), 220.95 KiB | 12.27 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# /content/Omnivoice
# ✅ Projekt a modely připraveny.

# %% [markdown]
# ## Spuštění `app.py`

# %% [markdown]
# Spuštění Omnivoce

# %%
import os

# Change to the project directory to ensure app.py runs correctly
# %cd {PROJECT_DIR}

# Run the app.py script
# !python app.py
# Out:
# Spouštění buněk s Python 3.13.12 vyžaduje balíček ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Vytvořte prostředí Pythonu</a> s požadovanými balíčky.
#
# Nebo nainstalujte ipykernel pomocí příkazu: c:/Users/ayaka/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall
