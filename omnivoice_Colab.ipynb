# %% [markdown]
# # 🚀 OmniVoice - Finální Stabilní Start
# **⚠️ DŮLEŽITÉ:** Před spuštěním zapni GPU: Runtime -> Change runtime type -> T4 GPU.

# %%
from google.colab import drive
import os
import sys

drive.mount('/content/drive')

REPO_URL = "https://github.com/Brkoszov/Omnivoice.git"
PROJECT_DIR = "/content/Omnivoice"
DRIVE_MODELS_PATH = "/content/drive/MyDrive/OmniVoice_Models"

if not os.path.exists(PROJECT_DIR):
    # !git clone {REPO_URL} {PROJECT_DIR}
else:
    # %cd {PROJECT_DIR}
    # !git pull

if os.getcwd() != PROJECT_DIR:
    # %cd {PROJECT_DIR}

MODELS_TARGET_DIR = os.path.join(PROJECT_DIR, "models")
if os.path.exists(MODELS_TARGET_DIR):
    # !rm -rf {MODELS_TARGET_DIR}
# !ln -s {DRIVE_MODELS_PATH} {MODELS_TARGET_DIR}
print("✅ Projekt a modely připraveny.")
# Out:
# Mounted at /content/drive
# Cloning into '/content/Omnivoice'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 152 (delta 43), reused 150 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (152/152), 224.00 KiB | 7.23 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# /content/Omnivoice
# ✅ Projekt a modely připraveny.

# %% [markdown]
# ## Spuštění `app.py`

# %% [markdown]
# Spuštění Omnivoce

# %%
import os

# Change to the project directory to ensure app.py runs correctly
# %cd {PROJECT_DIR}

# Run the app.py script
# !python app_Colab.py
# Out:
# /content/Omnivoice
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Loading model from /content/Omnivoice/models to cuda ...
# Loading weights: 100% 313/313 [00:25<00:00, 12.45it/s]
# Loading weights: 100% 527/527 [00:12<00:00, 42.33it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-06-24 08:12:37,168 huggingface_hub.utils._http WARNING: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 1.26k/1.26k [00:00<00:00, 732kB/s]
# model.safetensors: 100% 1.62G/1.62G [00:51<00:00, 31.6MB/s]
# Loading weights: 100% 587/587 [00:00<00:00, 1042.09it/s]
# generation_config.json: 100% 3.77k/3.77k [00:00<00:00, 16.2MB/s]
# tokenizer_config.json: 100% 283k/283k [00:00<00:00, 313MB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 30.3MB/s]
# tokenizer.json: 100% 2.71M/2.71M [00:00<00:00, 150MB/s]
# merges.txt: 100% 494k/494k [00:00<00:00, 105MB/s]
# normalizer.json: 100% 52.7k/52.7k [00:00<00:00, 75.5MB/s]
# added_tokens.json: 100% 34.6k/34.6k [00:00<00:00, 58.5MB/s]
# special_tokens_map.json: 100% 2.19k/2.19k [00:00<00:00, 7.04MB/s]
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 1.92MB/s]
# Model loaded successfully!
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://7b5d212cd13becb3c8.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# [transformers] Using custom `forced_decoder_ids` from the (generation) config. This is deprecated in favor of the `task` and `language` flags/config options.
# [transformers] Transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English. This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`. See https://github.com/huggingface/transformers/pull/28687 for more details.
# [transformers] A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> to see related `.generate()` flags.
# [transformers] A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> to see related `.generate()` flags.
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer WhisperTokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# 2026-06-24 08:15:17,946 omnivoice.models.omnivoice DEBUG: Auto-transcribed ref_text: Aby mu byly do konce války matkou i otcem. Zatímco my jsme měli války až po krk, tak ten chlapec kdeco viděl, to se mu líbilo, pořád by chtěl býval střílet, dával si plynovou masku, sám si dělal plyny, sám se otravoval.
# 2026-06-24 08:15:18,521 omnivoice.models.omnivoice DEBUG: Item 0 — text: na mraveniště šlápne slon. A z mraveniště se ozve hlasité "Ferdo uškrť ho" | ref_text: Aby mu byly do konce války matkou i otcem. Zatímco my jsme měli války až po krk, tak ten chlapec kdeco viděl, to se mu líbilo, pořád by chtěl býval střílet, dával si plynovou masku, sám si dělal plyny, sám se otravoval. | instruct: None | lang: None | target_tokens: 102
# 2026-06-24 08:16:13,886 omnivoice.models.omnivoice DEBUG: Auto-transcribed ref_text: Aby mu byly do konce války matkou i otcem. Zatímco my jsme měli války až po krk, tak ten chlapec kdeco viděl, to se mu líbilo, pořád by chtěl býval střílet, dával si plynovou masku, sám si dělal plyny, sám se otravoval.
# 2026-06-24 08:16:13,914 omnivoice.models.omnivoice DEBUG: Item 0 — text: na mraveniště šlápne slon. A z mraveniště se ozve hlasité "Ferdo uškrť ho" | ref_text: Aby mu byly do konce války matkou i otcem. Zatímco my jsme měli války až po krk, tak ten chlapec kdeco viděl, to se mu líbilo, pořád by chtěl býval střílet, dával si plynovou masku, sám si dělal plyny, sám se otravoval. | instruct: None | lang: None | target_tokens: 113
# 2026-06-24 08:16:47,567 omnivoice.models.omnivoice DEBUG: Auto-transcribed ref_text: Aby mu byly do konce války matkou i otcem. Zatímco my jsme měli války až po krk, tak ten chlapec kdeco viděl, to se mu líbilo, pořád by chtěl býval střílet, dával si plynovou masku, sám si dělal plyny, sám se otravoval.
# 2026-06-24 08:16:47,602 omnivoice.models.omnivoice DEBUG: Item 0 — text: na mraveniště šlápne slon. A z mraveniště se ozve hlasité "Ferdo uškrť ho". A to je celé. | ref_text: Aby mu byly do konce války matkou i otcem. Zatímco my jsme měli války až po krk, tak ten chlapec kdeco viděl, to se mu líbilo, pořád by chtěl býval střílet, dával si plynovou masku, sám si dělal plyny, sám se otravoval. | instruct: None | lang: None | target_tokens: 133
# 2026-06-24 08:17:30,400 omnivoice.models.omnivoice DEBUG: Auto-transcribed ref_text: Káčo, káčo, nebojte se, to jsem já, Čochtan, vodník ze Zlatý stoky, okres 3.
# 2026-06-24 08:17:30,463 omnivoice.models.omnivoice DEBUG: Item 0 — text: na mraveniště šlápne slon. A z mraveniště se ozve hlasité "Ferdo uškrť ho". A to je celé. | ref_text: Káčo, káčo, nebojte se, to jsem já, Čochtan, vodník ze Zlatý stoky, okres 3. | instruct: None | lang: None | target_tokens: 174
# 2026-06-24 08:19:41,448 omnivoice.models.omnivoice DEBUG: Auto-transcribed ref_text: V lese zabloudilo malé jehnátko. Čupitelo, čupitelo, čupitelo, nic netužil.
# 2026-06-24 08:19:41,514 omnivoice.models.omnivoice DEBUG: Item 0 — text: na mraveniště šlápne slon. A z mraveniště se ozve hlasité "Ferdo uškrť ho". A to je celé. | ref_text: V lese zabloudilo malé jehnátko. Čupitelo, čupitelo, čupitelo, nic netužil. | instruct: None | lang: None | target_tokens: 410
# 2026-06-24 08:20:27,431 omnivoice.models.omnivoice DEBUG: Auto-transcribed ref_text: V lese zabloudilo malé jehnátko. Čupitelo, čupitelo, čupitelo, nic netužil.
# 2026-06-24 08:20:27,458 omnivoice.models.omnivoice DEBUG: Item 0 — text: na mraveniště šlápne slon. A z mraveniště se ozve hlasité "Ferdo uškrť ho". A to je celé. | ref_text: V lese zabloudilo malé jehnátko. Čupitelo, čupitelo, čupitelo, nic netužil. | instruct: None | lang: None | target_tokens: 369
# 2026-06-24 08:21:17,546 omnivoice.models.omnivoice DEBUG: Auto-transcribed ref_text: ... zpráva pro radnou ženou, že dnes tudy pojede na Pražský hrad a že vlasta schystala vše, aby se nemohl navrátit a že jí v tom slouží i ta spanilá dívka. Pout zbavená děkovala.
# 2026-06-24 08:21:17,615 omnivoice.models.omnivoice DEBUG: Item 0 — text: na mraveniště šlápne slon. A z mraveniště se ozve hlasité "Ferdo uškrť ho". A to je celé. | ref_text: ... zpráva pro radnou ženou, že dnes tudy pojede na Pražský hrad a že vlasta schystala vše, aby se nemohl navrátit a že jí v tom slouží i ta spanilá dívka. Pout zbavená děkovala. | instruct: None | lang: None | target_tokens: 234
# 2026-06-24 08:21:54,461 omnivoice.models.omnivoice DEBUG: Auto-transcribed ref_text: A pak je N, pak je dvojité V, pak je zase E, pak je R a... Verich... No prostě Verich. Jan Verich uměl vyprávět.
# 2026-06-24 08:21:54,523 omnivoice.models.omnivoice DEBUG: Item 0 — text: na mraveniště šlápne slon. A z mraveniště se ozve hlasité "Ferdo uškrť ho". A to je celé. | ref_text: A pak je N, pak je dvojité V, pak je zase E, pak je R a... Verich... No prostě Verich. Jan Verich uměl vyprávět. | instruct: None | lang: None | target_tokens: 262
